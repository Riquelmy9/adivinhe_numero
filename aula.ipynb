# %% [markdown]
# <a href="https://colab.research.google.com/github/Riquelmy9/adivinhe_numero/blob/main/aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1

# %%
print("Alô, Mundo")
# Out:
# Alô, Mundo

# %% [markdown]
# Exercício 2

# %%
numero = int(input("Digite seu Número"))
print(f"o número informado foi o {numero}")
# Out:
# Digite seu Número10
# o número informado foi o 10

# %% [markdown]
# Exercício 3

# %%
num1 = float(input("Digite o primeiro número "))
num2 = float(input("Digite o segundo número "))
soma = num1 + num2
print(soma)
# Out:
# Digite o primeiro número 10
# Digite o segundo número 20
# 30.0

# %% [markdown]
# Exercício 4

# %%
num1 = float(input("Digite o primeiro número "))
num2 = float(input("Digite o segundo número "))
sub = num1 - num2
print(sub)
# Out:
# Digite o primeiro número 50
# Digite o segundo número 70
# -20.0

# %% [markdown]
# Exercício 5

# %%
num1 = float(input("Digite o primeiro número "))
num2 = float(input("Digite o segundo número "))
num3 = float(input("Digite o primeiro número "))
num4 = float(input("Digite o segundo número "))
media = (num1 + num2 + num3 + num4)/4
print(media)
# Out:
# Digite o primeiro número 18.9
# Digite o segundo número 30.7
# Digite o primeiro número 25.5
# Digite o segundo número 65.2
# 35.075

# %% [markdown]
# Exercício 6

# %%
m = int(input())
cm = (m * 100)
print(cm)
# Out:
# 70
# 7000

# %% [markdown]
# Exercício 7

# %%
cm = int(input())
m = (cm / 100)
print(m)
# Out:
# 7000
# 70.0
